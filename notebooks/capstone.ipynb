# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/Colab_files
# Out:
# dataset_yolov8.zip

# %%
# !unzip /content/drive/MyDrive/Colab_files/TeachTrack.v2i.yolov8.zip -d /content/dataset/
# Out:
# Archive:  /content/drive/MyDrive/Colab_files/TeachTrack.v2i.yolov8.zip
#   inflating: /content/dataset/README.dataset.txt
#   inflating: /content/dataset/README.roboflow.txt
#   inflating: /content/dataset/data.yaml
#    creating: /content/dataset/test/
#    creating: /content/dataset/test/images/
#  extracting: /content/dataset/test/images/40010003_jpg.rf.8fadb05e54186289beabb17c24bb899d.jpg
#  extracting: /content/dataset/test/images/40010046_jpg.rf.cd975028f135eea63678e450b752abef.jpg
#  extracting: /content/dataset/test/images/40010053_jpg.rf.571e351cc75b64b233e73601de8b5a3c.jpg
#  extracting: /content/dataset/test/images/40010075_jpg.rf.b707751f15d005aeeb5fb76c3226804c.jpg
#  extracting: /content/dataset/test/images/4001007_png.rf.1438e1e12edd0a68a2b7c3dae8ba7e35.jpg
#  extracting: /content/dataset/test/images/40010093_jpg.rf.21dc659614480975ad538dc4d6deb4d1.jpg
#  extracting: /content/dataset/test/images/40010099_jpg.rf.122fa972256b0fee97a7240b47b396fc.jpg
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/dataset/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files
files.download("runs/detect/train/weights/best.pt")

# %%
# !zip -r runs.zip runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/args.yaml (deflated 53%)
#   adding: runs/detect/train/weights/ (stored 0%)

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train2/weights/best.pt")

model.predict(
    source="https://media.assettype.com/deccanherald%2F2025-03-02%2Ft07evpxy%2FiStock-2075583750.jpg?rect=1%2C0%2C1253%2C705&w=undefined&auto=format%2Ccompress&fit=max",
    conf=0.4,
    save=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
