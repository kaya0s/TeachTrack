# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls /content/drive/MyDrive/teach_track_datasets/

# %%
# !unzip /content/drive/MyDrive/teach_track_datasets/TeachTrack.v9-v5.yolov8.zip -d /content/dataset/

# %%
# !pip install ultralytics

# %%
# !watch -n 1 nvidia-smi

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/dataset/data.yaml",
    epochs=50,
    imgsz=960,
    batch=16,
    multi_scale=False,
    patience=30,
    rect=True
)
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls /content/
# Out:
# dataset  drive	last.zip  runs	sample_data  yolo26n.pt  yolov8n.pt  yolov8s.pt

# %%
# !nvidia-smi
# Out:
# Fri Mar 27 12:23:41 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   75C    P0             34W /   70W |    5855MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import files
files.download("last.zip")

# %%
# !zip -r last.zip runs/detect/train13/
# Out:
#   adding: runs/detect/train13/ (stored 0%)
#   adding: runs/detect/train13/train_batch1.jpg (deflated 4%)
#   adding: runs/detect/train13/train_batch2.jpg (deflated 5%)
#   adding: runs/detect/train13/BoxP_curve.png (deflated 9%)
#   adding: runs/detect/train13/labels.jpg (deflated 31%)
#   adding: runs/detect/train13/results.png (deflated 7%)
#   adding: runs/detect/train13/val_batch2_pred.jpg (deflated 4%)
#   adding: runs/detect/train13/train_batch4401.jpg (deflated 3%)
#   adding: runs/detect/train13/val_batch2_labels.jpg (deflated 4%)
#   adding: runs/detect/train13/val_batch1_labels.jpg (deflated 4%)
#   adding: runs/detect/train13/BoxF1_curve.png (deflated 9%)
#   adding: runs/detect/train13/train_batch4400.jpg (deflated 4%)
#   adding: runs/detect/train13/train_batch4402.jpg (deflated 4%)
#   adding: runs/detect/train13/BoxPR_curve.png (deflated 11%)
#   adding: runs/detect/train13/confusion_matrix_normalized.png (deflated 21%)
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train2/weights/best.pt")

model.predict(
    source="https://media.assettype.com/deccanherald%2F2025-03-02%2Ft07evpxy%2FiStock-2075583750.jpg?rect=1%2C0%2C1253%2C705&w=undefined&auto=format%2Ccompress&fit=max",
    conf=0.4,
    save=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
